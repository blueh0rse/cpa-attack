# %%
import pandas as pd
import warnings
import numpy as np
import numpy.typing as npt
import aes
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

warnings.filterwarnings("ignore", category=SyntaxWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

io_data = pd.read_csv('data/dpa-aes/aes_data.txt', header=None)
io_data = io_data.apply(lambda x: x.str.replace(' ', '')) # https://stackoverflow.com/questions/40083266/replace-comma-with-dot-pandas
io_data['in'] = io_data[0].str[:32]
io_data['out'] = io_data[0].str[32:]
io_data = io_data.drop(columns=[0])

# https://stackoverflow.com/questions/40083266/replace-comma-with-dot-pandas
traces = pd.read_csv('data/dpa-aes/aes_samples.txt', sep='\s+', decimal=',', header=None)
traces_np = traces.to_numpy()
# print(io_data['out'].iloc[0])

# %%
def hamming_weight(n):
    count = 0
    while n:
        count += n & 1
        n >>= 1
    return count

hamming_weights = np.array([hamming_weight(i) for i in range(256)])

# %%
numtraces = traces.shape[0]
numsamples = traces.shape[1]

sbox = np.asarray([], dtype=np.uint8)

def xor_sbox(pt, keyguess):
	return sbox[pt ^ keyguess]

bestguess = [0] * 16

for bnum in range(1): # 16
	maxcpa = np.zeros(256)
	for kguess in range(256):
		print(f'subkey {bnum}, hyp {hex(kguess)}')

		sumnum = np.zeros(numsamples)
		sumden1 = np.zeros(numsamples)
		sumden2 = np.zeros(numsamples)

		hyp = np.zeros(numtraces)
		for tnum, trace in enumerate(traces):
			tmp = [int(io_data['in'][tnum][i:i + 2], 16) for i in range(0, 32, 2)]
			in_matrix = np.asarray(tmp, dtype=np.uint8)
			hyp[tnum] = hamming_weights[xor_sbox(in_matrix[bnum], kguess)]

		meanh = np.mean(hyp, dtype=np.float64)
		meant = np.mean(traces, axis=0)

		for tnum in range(numtraces):
			hdiff = (hyp[tnum] - meanh)
			tdiff = traces_np[tnum, :] - meant

			sumnum = sumnum + (hdiff * tdiff)
			sumden1 = sumden1 + hdiff * hdiff
			sumden2 = sumden2 + tdiff * tdiff

		maxcpa[kguess] = np.max(np.abs(sumnum / np.sqrt(sumden1 * sumden2)))

		print(f'{maxcpa[kguess]=}')

	bestguess[bnum] = np.argmax(maxcpa)

print('Best Key Guess:')
for b in bestguess:
	print(hex(b))
# Out:
# subkey 0, hyp 0x0
# maxcpa[kguess]=0.0420113039426524
# subkey 0, hyp 0x1
# maxcpa[kguess]=0.03874844606606725
# subkey 0, hyp 0x2
# maxcpa[kguess]=0.03852915515004502
# subkey 0, hyp 0x3
# maxcpa[kguess]=0.05281510343466979
# subkey 0, hyp 0x4
# maxcpa[kguess]=0.05253186403152655
# subkey 0, hyp 0x5
# maxcpa[kguess]=0.045338741731790595
# subkey 0, hyp 0x6
# maxcpa[kguess]=0.03801248294687602
# subkey 0, hyp 0x7
# maxcpa[kguess]=0.05069000219922463
# subkey 0, hyp 0x8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 35
#      33 	sumnum = sumnum + (hdiff * tdiff)
#      34 	sumden1 = sumden1 + hdiff * hdiff
# ---> 35 	sumden2 = sumden2 + tdiff * tdiff
#      37 maxcpa[kguess] = np.max(np.abs(sumnum / np.sqrt(sumden1 * sumden2)))
#      39 print(f'{maxcpa[kguess]=}')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:102, in OpsMixin.__add__(self, other)
#     100 @unpack_zerodim_and_defer("__add__")
#     101 def __add__(self, other):
# --> 102     return self._arith_method(other, operator.add)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6259, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
#    6258     self, other = ops.align_method_SERIES(self, other)
# -> 6259     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:1327, in IndexOpsMixin._arith_method(self, other, op)
#    1324 with np.errstate(all="ignore"):
#    1325     result = ops.arithmetic_op(lvalues, rvalues, op)
# -> 1327 return self._construct_result(result, name=res_name)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:3223, in Series._construct_result(self, result, name)
#    3219     return (res1, res2)
#    3221 # We do not pass dtype to ensure that the Series constructor
#    3222 #  does inference in the case where `result` has object-dtype.
# -> 3223 out = self._constructor(result, index=self.index)
#    3224 out = out.__finalize__(self)
#    3226 # Set the result's name after __finalize__ is called because __finalize__
#    3227 #  would set it back to self.name
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:420, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     417         data = data._values.copy()
#     418     copy = False
# --> 420 elif isinstance(data, np.ndarray):
#     421     if len(data.dtype):
#     422         # GH#13296 we are dealing with a compound dtype, which
#     423         #  should be treated as 2D
#     424         raise ValueError(
#     425             "Cannot construct a Series from an ndarray with "
#     426             "compound dtype.  Use DataFrame instead."
#     427         )
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd

# Load traces and inputs
traces = pd.read_csv('data/dpa-aes/aes_samples.txt', sep='\s+', decimal=',', header=None).values
num_samples = traces.shape[1]
num_traces = traces.shape[0]

io_data = pd.read_csv('data/dpa-aes/aes_data.txt', header=None)
io_data = io_data.apply(lambda x: x.str.replace(' ', ''))
io_data['in'] = io_data[0].str[:32]
io_data['out'] = io_data[0].str[32:]
io_data = io_data.drop(columns=[0])
inputs = io_data['in'].values

# Define the Sbox and its inverse
sbox = np.asarray([], dtype=np.uint8) # Load the AES Sbox # Load the AES Sbox

# Define the hypothetical power consumption model
def power_model(byte, value):
    """
    Compute the hypothetical power consumption for a given byte and value.
    """
    output = sbox[byte ^ value]
    hamming_weight = hamming_weights[output]
    return hamming_weight

# Perform CPA attack
for byte_index in range(16):
    print(f'box {byte_index}')
    max_correlation = 0
    best_key_guess = None

    for key_guess in range(256):
        hypothetical_values = []
        for trace_index in range(num_traces):
            input_bytes = np.array([int(inputs[trace_index][i:i+2], 16) for i in range(0, len(inputs[trace_index]), 2)])
            hypothetical_values.append(power_model(input_bytes[byte_index], key_guess))
        hypothetical_values = np.array(hypothetical_values)

        for sample_index in range(num_samples):
            correlation = np.corrcoef(hypothetical_values, traces[:, sample_index])[0, 1]
            if abs(correlation) > max_correlation:
                max_correlation = abs(correlation)
                best_key_guess = key_guess

    print(f"Recovered key byte {byte_index}: {best_key_guess:02x}")
# Out:
# box 0
# Recovered key byte 0: ca
# box 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 42
#      39 hypothetical_values = np.array(hypothetical_values)
#      41 for sample_index in range(num_samples):
# ---> 42     correlation = np.corrcoef(hypothetical_values, traces[:, sample_index])[0, 1]
#      43     if abs(correlation) > max_correlation:
#      44         max_correlation = abs(correlation)
#
# File <__array_function__ internals>:5, in corrcoef(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/numpy/lib/function_base.py:2698, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2694 # Clip real and imaginary parts to [-1, 1].  This does not guarantee
#    2695 # abs(a[i,j]) <= 1 for complex arrays, but is the best we can do without
#    2696 # excessive work.
#    2697 np.clip(c.real, -1, 1, out=c.real)
# -> 2698 if np.iscomplexobj(c):
#    2699     np.clip(c.imag, -1, 1, out=c.imag)
#    2701 return c
#
# File <__array_function__ internals>:5, in iscomplexobj(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/numpy/lib/type_check.py:341, in iscomplexobj(x)
#     339 except AttributeError:
#     340     type_ = asarray(x).dtype.type
# --> 341 return issubclass(type_, _nx.complexfloating)
#
# KeyboardInterrupt:

# %%
all_hamming_weights_per_box = np.zeros((5000, 16), dtype=np.uint8)
coeff = np.zeros((256, 16))

for key_guess in range(256):
    simulated_traces = np.zeros((5000, 528))
    print(f'Analyzing key byte guess: {hex(key_guess)}')
    key_guess_matrix = np.full((4, 4), key_guess, dtype=np.uint8)
    for tnum, in_data in enumerate(io_data['in']):
        # fancy way to parse hex data and put it into a 4x4 matrix
        tmp = [int(in_data[i:i + 2], 16) for i in range(0, len(in_data), 2)]
        in_matrix = np.asarray(tmp, dtype=np.uint8).reshape(4, 4)

        added_key = aes.add_round_key(in_matrix, key_guess_matrix)
        sub_out = aes.sub_bytes(added_key, False).flatten()

        for bnum in range(16):
            all_hamming_weights_per_box[tnum][bnum] = hamming_weights[sub_out[bnum]]

    for bnum in range(16):
        simulated_traces_sum = np.sum((traces.T * all_hamming_weights_per_box[:, bnum]).T, axis=0)
        coeff[key_guess][bnum] = np.abs(pearsonr(np.sum(traces, axis=0), simulated_traces_sum)[0])
# Out:
# Analyzing key byte guess: 0x0
# Analyzing key byte guess: 0x1
# Analyzing key byte guess: 0x2
# Analyzing key byte guess: 0x3
# Analyzing key byte guess: 0x4
# Analyzing key byte guess: 0x5
# Analyzing key byte guess: 0x6
# Analyzing key byte guess: 0x7
# Analyzing key byte guess: 0x8
# Analyzing key byte guess: 0x9
# Analyzing key byte guess: 0xa
# Analyzing key byte guess: 0xb
# Analyzing key byte guess: 0xc
# Analyzing key byte guess: 0xd
# Analyzing key byte guess: 0xe
# Analyzing key byte guess: 0xf
# Analyzing key byte guess: 0x10
# Analyzing key byte guess: 0x11
# Analyzing key byte guess: 0x12
# Analyzing key byte guess: 0x13
# Analyzing key byte guess: 0x14
# Analyzing key byte guess: 0x15
# Analyzing key byte guess: 0x16
# Analyzing key byte guess: 0x17
# Analyzing key byte guess: 0x18
# Analyzing key byte guess: 0x19
# Analyzing key byte guess: 0x1a
# Analyzing key byte guess: 0x1b
# Analyzing key byte guess: 0x1c
# Analyzing key byte guess: 0x1d
# Analyzing key byte guess: 0x1e
# Analyzing key byte guess: 0x1f
# Analyzing key byte guess: 0x20
# Analyzing key byte guess: 0x21
# Analyzing key byte guess: 0x22
# Analyzing key byte guess: 0x23
# Analyzing key byte guess: 0x24
# Analyzing key byte guess: 0x25
# Analyzing key byte guess: 0x26
# Analyzing key byte guess: 0x27
# Analyzing key byte guess: 0x28
# Analyzing key byte guess: 0x29
# Analyzing key byte guess: 0x2a
# Analyzing key byte guess: 0x2b
# Analyzing key byte guess: 0x2c
# Analyzing key byte guess: 0x2d
# Analyzing key byte guess: 0x2e
# Analyzing key byte guess: 0x2f
# Analyzing key byte guess: 0x30
# Analyzing key byte guess: 0x31
# Analyzing key byte guess: 0x32
# Analyzing key byte guess: 0x33
# Analyzing key byte guess: 0x34
# Analyzing key byte guess: 0x35
# Analyzing key byte guess: 0x36
# Analyzing key byte guess: 0x37
# Analyzing key byte guess: 0x38
# Analyzing key byte guess: 0x39
# Analyzing key byte guess: 0x3a
# Analyzing key byte guess: 0x3b
# Analyzing key byte guess: 0x3c
# Analyzing key byte guess: 0x3d
# Analyzing key byte guess: 0x3e
# Analyzing key byte guess: 0x3f
# Analyzing key byte guess: 0x40
# Analyzing key byte guess: 0x41
# Analyzing key byte guess: 0x42
# Analyzing key byte guess: 0x43
# Analyzing key byte guess: 0x44
# Analyzing key byte guess: 0x45
# Analyzing key byte guess: 0x46
# Analyzing key byte guess: 0x47
# Analyzing key byte guess: 0x48
# Analyzing key byte guess: 0x49
# Analyzing key byte guess: 0x4a
# Analyzing key byte guess: 0x4b
# Analyzing key byte guess: 0x4c
# Analyzing key byte guess: 0x4d
# Analyzing key byte guess: 0x4e
# Analyzing key byte guess: 0x4f
# Analyzing key byte guess: 0x50
# Analyzing key byte guess: 0x51
# Analyzing key byte guess: 0x52
# Analyzing key byte guess: 0x53
# Analyzing key byte guess: 0x54
# Analyzing key byte guess: 0x55
# Analyzing key byte guess: 0x56
# Analyzing key byte guess: 0x57
# Analyzing key byte guess: 0x58
# Analyzing key byte guess: 0x59
# Analyzing key byte guess: 0x5a
# Analyzing key byte guess: 0x5b
# Analyzing key byte guess: 0x5c
# Analyzing key byte guess: 0x5d
# Analyzing key byte guess: 0x5e
# Analyzing key byte guess: 0x5f
# Analyzing key byte guess: 0x60
# Analyzing key byte guess: 0x61
# Analyzing key byte guess: 0x62
# Analyzing key byte guess: 0x63
# Analyzing key byte guess: 0x64
# Analyzing key byte guess: 0x65
# Analyzing key byte guess: 0x66
# Analyzing key byte guess: 0x67
# Analyzing key byte guess: 0x68
# Analyzing key byte guess: 0x69
# Analyzing key byte guess: 0x6a
# Analyzing key byte guess: 0x6b
# Analyzing key byte guess: 0x6c
# Analyzing key byte guess: 0x6d
# Analyzing key byte guess: 0x6e
# Analyzing key byte guess: 0x6f
# Analyzing key byte guess: 0x70
# Analyzing key byte guess: 0x71
# Analyzing key byte guess: 0x72
# Analyzing key byte guess: 0x73
# Analyzing key byte guess: 0x74
# Analyzing key byte guess: 0x75
# Analyzing key byte guess: 0x76
# Analyzing key byte guess: 0x77
# Analyzing key byte guess: 0x78
# Analyzing key byte guess: 0x79
# Analyzing key byte guess: 0x7a
# Analyzing key byte guess: 0x7b
# Analyzing key byte guess: 0x7c
# Analyzing key byte guess: 0x7d
# Analyzing key byte guess: 0x7e
# Analyzing key byte guess: 0x7f
# Analyzing key byte guess: 0x80
# Analyzing key byte guess: 0x81
# Analyzing key byte guess: 0x82
# Analyzing key byte guess: 0x83
# Analyzing key byte guess: 0x84
# Analyzing key byte guess: 0x85
# Analyzing key byte guess: 0x86
# Analyzing key byte guess: 0x87
# Analyzing key byte guess: 0x88
# Analyzing key byte guess: 0x89
# Analyzing key byte guess: 0x8a
# Analyzing key byte guess: 0x8b
# Analyzing key byte guess: 0x8c
# Analyzing key byte guess: 0x8d
# Analyzing key byte guess: 0x8e
# Analyzing key byte guess: 0x8f
# Analyzing key byte guess: 0x90
# Analyzing key byte guess: 0x91
# Analyzing key byte guess: 0x92
# Analyzing key byte guess: 0x93
# Analyzing key byte guess: 0x94
# Analyzing key byte guess: 0x95
# Analyzing key byte guess: 0x96
# Analyzing key byte guess: 0x97
# Analyzing key byte guess: 0x98
# Analyzing key byte guess: 0x99
# Analyzing key byte guess: 0x9a
# Analyzing key byte guess: 0x9b
# Analyzing key byte guess: 0x9c
# Analyzing key byte guess: 0x9d
# Analyzing key byte guess: 0x9e
# Analyzing key byte guess: 0x9f
# Analyzing key byte guess: 0xa0
# Analyzing key byte guess: 0xa1
# Analyzing key byte guess: 0xa2
# Analyzing key byte guess: 0xa3
# Analyzing key byte guess: 0xa4
# Analyzing key byte guess: 0xa5
# Analyzing key byte guess: 0xa6
# Analyzing key byte guess: 0xa7
# Analyzing key byte guess: 0xa8
# Analyzing key byte guess: 0xa9
# Analyzing key byte guess: 0xaa
# Analyzing key byte guess: 0xab
# Analyzing key byte guess: 0xac
# Analyzing key byte guess: 0xad
# Analyzing key byte guess: 0xae
# Analyzing key byte guess: 0xaf
# Analyzing key byte guess: 0xb0
# Analyzing key byte guess: 0xb1
# Analyzing key byte guess: 0xb2
# Analyzing key byte guess: 0xb3
# Analyzing key byte guess: 0xb4
# Analyzing key byte guess: 0xb5
# Analyzing key byte guess: 0xb6
# Analyzing key byte guess: 0xb7
# Analyzing key byte guess: 0xb8
# Analyzing key byte guess: 0xb9
# Analyzing key byte guess: 0xba
# Analyzing key byte guess: 0xbb
# Analyzing key byte guess: 0xbc
# Analyzing key byte guess: 0xbd
# Analyzing key byte guess: 0xbe
# Analyzing key byte guess: 0xbf
# Analyzing key byte guess: 0xc0
# Analyzing key byte guess: 0xc1
# Analyzing key byte guess: 0xc2
# Analyzing key byte guess: 0xc3
# Analyzing key byte guess: 0xc4
# Analyzing key byte guess: 0xc5
# Analyzing key byte guess: 0xc6
# Analyzing key byte guess: 0xc7
# Analyzing key byte guess: 0xc8
# Analyzing key byte guess: 0xc9
# Analyzing key byte guess: 0xca
# Analyzing key byte guess: 0xcb
# Analyzing key byte guess: 0xcc
# Analyzing key byte guess: 0xcd
# Analyzing key byte guess: 0xce
# Analyzing key byte guess: 0xcf
# Analyzing key byte guess: 0xd0
# Analyzing key byte guess: 0xd1
# Analyzing key byte guess: 0xd2
# Analyzing key byte guess: 0xd3
# Analyzing key byte guess: 0xd4
# Analyzing key byte guess: 0xd5
# Analyzing key byte guess: 0xd6
# Analyzing key byte guess: 0xd7
# Analyzing key byte guess: 0xd8
# Analyzing key byte guess: 0xd9
# Analyzing key byte guess: 0xda
# Analyzing key byte guess: 0xdb
# Analyzing key byte guess: 0xdc
# Analyzing key byte guess: 0xdd
# Analyzing key byte guess: 0xde
# Analyzing key byte guess: 0xdf
# Analyzing key byte guess: 0xe0
# Analyzing key byte guess: 0xe1
# Analyzing key byte guess: 0xe2
# Analyzing key byte guess: 0xe3
# Analyzing key byte guess: 0xe4
# Analyzing key byte guess: 0xe5
# Analyzing key byte guess: 0xe6
# Analyzing key byte guess: 0xe7
# Analyzing key byte guess: 0xe8
# Analyzing key byte guess: 0xe9
# Analyzing key byte guess: 0xea
# Analyzing key byte guess: 0xeb
# Analyzing key byte guess: 0xec
# Analyzing key byte guess: 0xed
# Analyzing key byte guess: 0xee
# Analyzing key byte guess: 0xef
# Analyzing key byte guess: 0xf0
# Analyzing key byte guess: 0xf1
# Analyzing key byte guess: 0xf2
# Analyzing key byte guess: 0xf3
# Analyzing key byte guess: 0xf4
# Analyzing key byte guess: 0xf5
# Analyzing key byte guess: 0xf6
# Analyzing key byte guess: 0xf7
# Analyzing key byte guess: 0xf8
# Analyzing key byte guess: 0xf9
# Analyzing key byte guess: 0xfa
# Analyzing key byte guess: 0xfb
# Analyzing key byte guess: 0xfc
# Analyzing key byte guess: 0xfd
# Analyzing key byte guess: 0xfe
# Analyzing key byte guess: 0xff

# %%
np.sum((traces.T * all_hamming_weights_per_box[:, 0]).T, axis=0).shape
# Out:
# (528,)

# %%
np.set_printoptions(formatter={'int':hex})
np.argsort(coeff, axis=0)[0]
# Out:
# array([0xca, 0xfe, 0xba, 0xbe, 0xca, 0xfe, 0xba, 0xbe, 0xca, 0xfe, 0xba,
#        0xbe, 0xca, 0xfe, 0xba, 0xbe])

# %%
all_hamming_weights_per_box3 = np.zeros((5000, 16), dtype=np.uint8)
coeff2 = np.zeros((16, 256))

for key_guess in range(1):
    print(f'Analyzing key byte guess: {hex(key_guess)}')
    key_guess_matrix = np.full((4, 4), key_guess, dtype=np.uint8)
    for tnum, in_data in enumerate(io_data['in']):
        # fancy way to parse hex data and put it into a 4x4 matrix
        tmp = [int(in_data[i:i + 2], 16) for i in range(0, len(in_data), 2)]
        in_matrix = np.asarray(tmp, dtype=np.uint8).reshape(4, 4)

        added_key = aes.add_round_key(in_matrix, key_guess_matrix)
        sub_out = aes.sub_bytes(added_key, False).flatten()

        for byte_index in range(sub_out.shape[0]):
            all_hamming_weights_per_box3[tnum][byte_index] = hamming_weights[sub_out[byte_index]]

    # for box in range(16):
    #     guess_box_weights = all_hamming_weights_per_box2[:, key_guess, box]
    #     WxH = (traces.T * guess_box_weights).T
    #     EWxH = np.sum(WxH, axis=0)

    #     Ew = np.sum(traces, axis=0)
    #     Eh = np.sum(guess_box_weights)

    #     Ew2 = np.sum(np.square(traces), axis=0)
    #     Ew_squared = np.square(Ew)

    #     Eh2 = np.sum(np.square(guess_box_weights), axis=0)
    #     Eh_squared = np.square(Eh)

    #     top = (5000 * EWxH) - (Eh * Ew)
    #     bottom = np.sqrt((5000 * Ew2) - Ew_squared) * np.sqrt((5000 * Eh2) - Eh_squared)
    #     coeff2[box][key_guess] = np.max(top / bottom)
# Out:
# Analyzing key byte guess: 0x0

# %%
all_hamming_weights_per_box2 = np.zeros((5000, 256, 16), dtype=np.uint8)
coeff2 = np.zeros((16, 256))

for key_guess in range(256):
    print(f'Analyzing key byte guess: {hex(key_guess)}')
    key_guess_matrix = np.full((4, 4), key_guess, dtype=np.uint8)
    for tnum, in_data in enumerate(io_data['in']):
        # fancy way to parse hex data and put it into a 4x4 matrix
        tmp = [int(in_data[i:i + 2], 16) for i in range(0, len(in_data), 2)]
        in_matrix = np.asarray(tmp, dtype=np.uint8).reshape(4, 4)

        added_key = aes.add_round_key(in_matrix, key_guess_matrix)
        sub_out = aes.sub_bytes(added_key, False).flatten()

        for byte_index in range(sub_out.shape[0]):
            all_hamming_weights_per_box2[tnum][key_guess][byte_index] = hamming_weights[sub_out[byte_index]]

    for box in range(16):
        guess_box_weights = all_hamming_weights_per_box2[:, key_guess, box]
        WxH = (traces.T * guess_box_weights).T
        EWxH = np.sum(WxH, axis=0)

        Ew = np.sum(traces, axis=0)
        Eh = np.sum(guess_box_weights)

        Ew2 = np.sum(np.square(traces), axis=0)
        Ew_squared = np.square(Ew)

        Eh2 = np.sum(np.square(guess_box_weights), axis=0)
        Eh_squared = np.square(Eh)

        top = (5000 * EWxH) - (Eh * Ew)
        bottom = np.sqrt((5000 * Ew2) - Ew_squared) * np.sqrt((5000 * Eh2) - Eh_squared)
        coeff2[box][key_guess] = np.max(top / bottom)
# Out:
# Analyzing key byte guess: 0x0
# Analyzing key byte guess: 0x1
# Analyzing key byte guess: 0x2
# Analyzing key byte guess: 0x3
# Analyzing key byte guess: 0x4
# Analyzing key byte guess: 0x5
# Analyzing key byte guess: 0x6
# Analyzing key byte guess: 0x7
# Analyzing key byte guess: 0x8
# Analyzing key byte guess: 0x9
# Analyzing key byte guess: 0xa
# Analyzing key byte guess: 0xb
# Analyzing key byte guess: 0xc
# Analyzing key byte guess: 0xd
# Analyzing key byte guess: 0xe
# Analyzing key byte guess: 0xf
# Analyzing key byte guess: 0x10
# Analyzing key byte guess: 0x11
# Analyzing key byte guess: 0x12
# Analyzing key byte guess: 0x13
# Analyzing key byte guess: 0x14
# Analyzing key byte guess: 0x15
# Analyzing key byte guess: 0x16
# Analyzing key byte guess: 0x17
# Analyzing key byte guess: 0x18
# Analyzing key byte guess: 0x19
# Analyzing key byte guess: 0x1a
# Analyzing key byte guess: 0x1b
# Analyzing key byte guess: 0x1c
# Analyzing key byte guess: 0x1d
# Analyzing key byte guess: 0x1e
# Analyzing key byte guess: 0x1f
# Analyzing key byte guess: 0x20
# Analyzing key byte guess: 0x21
# Analyzing key byte guess: 0x22
# Analyzing key byte guess: 0x23
# Analyzing key byte guess: 0x24
# Analyzing key byte guess: 0x25
# Analyzing key byte guess: 0x26
# Analyzing key byte guess: 0x27
# Analyzing key byte guess: 0x28
# Analyzing key byte guess: 0x29
# Analyzing key byte guess: 0x2a
# Analyzing key byte guess: 0x2b
# Analyzing key byte guess: 0x2c
# Analyzing key byte guess: 0x2d
# Analyzing key byte guess: 0x2e
# Analyzing key byte guess: 0x2f
# Analyzing key byte guess: 0x30
# Analyzing key byte guess: 0x31
# Analyzing key byte guess: 0x32
# Analyzing key byte guess: 0x33
# Analyzing key byte guess: 0x34
# Analyzing key byte guess: 0x35
# Analyzing key byte guess: 0x36
# Analyzing key byte guess: 0x37
# Analyzing key byte guess: 0x38
# Analyzing key byte guess: 0x39
# Analyzing key byte guess: 0x3a
# Analyzing key byte guess: 0x3b
# Analyzing key byte guess: 0x3c
# Analyzing key byte guess: 0x3d
# Analyzing key byte guess: 0x3e
# Analyzing key byte guess: 0x3f
# Analyzing key byte guess: 0x40
# Analyzing key byte guess: 0x41
# Analyzing key byte guess: 0x42
# Analyzing key byte guess: 0x43
# Analyzing key byte guess: 0x44
# Analyzing key byte guess: 0x45
# Analyzing key byte guess: 0x46
# Analyzing key byte guess: 0x47
# Analyzing key byte guess: 0x48
# Analyzing key byte guess: 0x49
# Analyzing key byte guess: 0x4a
# Analyzing key byte guess: 0x4b
# Analyzing key byte guess: 0x4c
# Analyzing key byte guess: 0x4d
# Analyzing key byte guess: 0x4e
# Analyzing key byte guess: 0x4f
# Analyzing key byte guess: 0x50
# Analyzing key byte guess: 0x51
# Analyzing key byte guess: 0x52
# Analyzing key byte guess: 0x53
# Analyzing key byte guess: 0x54
# Analyzing key byte guess: 0x55
# Analyzing key byte guess: 0x56
# Analyzing key byte guess: 0x57
# Analyzing key byte guess: 0x58
# Analyzing key byte guess: 0x59
# Analyzing key byte guess: 0x5a
# Analyzing key byte guess: 0x5b
# Analyzing key byte guess: 0x5c
# Analyzing key byte guess: 0x5d
# Analyzing key byte guess: 0x5e
# Analyzing key byte guess: 0x5f
# Analyzing key byte guess: 0x60
# Analyzing key byte guess: 0x61
# Analyzing key byte guess: 0x62
# Analyzing key byte guess: 0x63
# Analyzing key byte guess: 0x64
# Analyzing key byte guess: 0x65
# Analyzing key byte guess: 0x66
# Analyzing key byte guess: 0x67
# Analyzing key byte guess: 0x68
# Analyzing key byte guess: 0x69
# Analyzing key byte guess: 0x6a
# Analyzing key byte guess: 0x6b
# Analyzing key byte guess: 0x6c
# Analyzing key byte guess: 0x6d
# Analyzing key byte guess: 0x6e
# Analyzing key byte guess: 0x6f
# Analyzing key byte guess: 0x70
# Analyzing key byte guess: 0x71
# Analyzing key byte guess: 0x72
# Analyzing key byte guess: 0x73
# Analyzing key byte guess: 0x74
# Analyzing key byte guess: 0x75
# Analyzing key byte guess: 0x76
# Analyzing key byte guess: 0x77
# Analyzing key byte guess: 0x78
# Analyzing key byte guess: 0x79
# Analyzing key byte guess: 0x7a
# Analyzing key byte guess: 0x7b
# Analyzing key byte guess: 0x7c
# Analyzing key byte guess: 0x7d
# Analyzing key byte guess: 0x7e
# Analyzing key byte guess: 0x7f
# Analyzing key byte guess: 0x80
# Analyzing key byte guess: 0x81
# Analyzing key byte guess: 0x82
# Analyzing key byte guess: 0x83
# Analyzing key byte guess: 0x84
# Analyzing key byte guess: 0x85
# Analyzing key byte guess: 0x86
# Analyzing key byte guess: 0x87
# Analyzing key byte guess: 0x88
# Analyzing key byte guess: 0x89
# Analyzing key byte guess: 0x8a
# Analyzing key byte guess: 0x8b
# Analyzing key byte guess: 0x8c
# Analyzing key byte guess: 0x8d
# Analyzing key byte guess: 0x8e
# Analyzing key byte guess: 0x8f
# Analyzing key byte guess: 0x90
# Analyzing key byte guess: 0x91
# Analyzing key byte guess: 0x92
# Analyzing key byte guess: 0x93
# Analyzing key byte guess: 0x94
# Analyzing key byte guess: 0x95
# Analyzing key byte guess: 0x96
# Analyzing key byte guess: 0x97
# Analyzing key byte guess: 0x98
# Analyzing key byte guess: 0x99
# Analyzing key byte guess: 0x9a
# Analyzing key byte guess: 0x9b
# Analyzing key byte guess: 0x9c
# Analyzing key byte guess: 0x9d
# Analyzing key byte guess: 0x9e
# Analyzing key byte guess: 0x9f
# Analyzing key byte guess: 0xa0
# Analyzing key byte guess: 0xa1
# Analyzing key byte guess: 0xa2
# Analyzing key byte guess: 0xa3
# Analyzing key byte guess: 0xa4
# Analyzing key byte guess: 0xa5
# Analyzing key byte guess: 0xa6
# Analyzing key byte guess: 0xa7
# Analyzing key byte guess: 0xa8
# Analyzing key byte guess: 0xa9
# Analyzing key byte guess: 0xaa
# Analyzing key byte guess: 0xab
# Analyzing key byte guess: 0xac
# Analyzing key byte guess: 0xad
# Analyzing key byte guess: 0xae
# Analyzing key byte guess: 0xaf
# Analyzing key byte guess: 0xb0
# Analyzing key byte guess: 0xb1
# Analyzing key byte guess: 0xb2
# Analyzing key byte guess: 0xb3
# Analyzing key byte guess: 0xb4
# Analyzing key byte guess: 0xb5
# Analyzing key byte guess: 0xb6
# Analyzing key byte guess: 0xb7
# Analyzing key byte guess: 0xb8
# Analyzing key byte guess: 0xb9
# Analyzing key byte guess: 0xba
# Analyzing key byte guess: 0xbb
# Analyzing key byte guess: 0xbc
# Analyzing key byte guess: 0xbd
# Analyzing key byte guess: 0xbe
# Analyzing key byte guess: 0xbf
# Analyzing key byte guess: 0xc0
# Analyzing key byte guess: 0xc1
# Analyzing key byte guess: 0xc2
# Analyzing key byte guess: 0xc3
# Analyzing key byte guess: 0xc4
# Analyzing key byte guess: 0xc5
# Analyzing key byte guess: 0xc6
# Analyzing key byte guess: 0xc7
# Analyzing key byte guess: 0xc8
# Analyzing key byte guess: 0xc9
# Analyzing key byte guess: 0xca
# Analyzing key byte guess: 0xcb
# Analyzing key byte guess: 0xcc
# Analyzing key byte guess: 0xcd
# Analyzing key byte guess: 0xce
# Analyzing key byte guess: 0xcf
# Analyzing key byte guess: 0xd0
# Analyzing key byte guess: 0xd1
# Analyzing key byte guess: 0xd2
# Analyzing key byte guess: 0xd3
# Analyzing key byte guess: 0xd4
# Analyzing key byte guess: 0xd5
# Analyzing key byte guess: 0xd6
# Analyzing key byte guess: 0xd7
# Analyzing key byte guess: 0xd8
# Analyzing key byte guess: 0xd9
# Analyzing key byte guess: 0xda
# Analyzing key byte guess: 0xdb
# Analyzing key byte guess: 0xdc
# Analyzing key byte guess: 0xdd
# Analyzing key byte guess: 0xde
# Analyzing key byte guess: 0xdf
# Analyzing key byte guess: 0xe0
# Analyzing key byte guess: 0xe1
# Analyzing key byte guess: 0xe2
# Analyzing key byte guess: 0xe3
# Analyzing key byte guess: 0xe4
# Analyzing key byte guess: 0xe5
# Analyzing key byte guess: 0xe6
# Analyzing key byte guess: 0xe7
# Analyzing key byte guess: 0xe8
# Analyzing key byte guess: 0xe9
# Analyzing key byte guess: 0xea
# Analyzing key byte guess: 0xeb
# Analyzing key byte guess: 0xec
# Analyzing key byte guess: 0xed
# Analyzing key byte guess: 0xee
# Analyzing key byte guess: 0xef
# Analyzing key byte guess: 0xf0
# Analyzing key byte guess: 0xf1
# Analyzing key byte guess: 0xf2
# Analyzing key byte guess: 0xf3
# Analyzing key byte guess: 0xf4
# Analyzing key byte guess: 0xf5
# Analyzing key byte guess: 0xf6
# Analyzing key byte guess: 0xf7
# Analyzing key byte guess: 0xf8
# Analyzing key byte guess: 0xf9
# Analyzing key byte guess: 0xfa
# Analyzing key byte guess: 0xfb
# Analyzing key byte guess: 0xfc
# Analyzing key byte guess: 0xfd
# Analyzing key byte guess: 0xfe
# Analyzing key byte guess: 0xff

# %%
# This can be done inside the main loop...
# for box in range(16):
#     for guess in range(2**8):
#         guess_box_weights = all_hamming_weights_per_box[:, guess, box]
#         WxH = (traces.T * guess_box_weights).T
#         EWxH = np.sum(WxH, axis=0)

#         Ew = np.sum(traces, axis=0)
#         Eh = np.sum(guess_box_weights)

#         Ew2 = np.sum(np.square(traces), axis=0)
#         Ew_squared = np.square(Ew)

#         Eh2 = np.sum(np.square(guess_box_weights), axis=0)
#         Eh_squared = np.square(Eh)

#         top = (5000 * EWxH) - (Eh * Ew)
#         bottom = np.sqrt((5000 * Ew2) - Ew_squared) * np.sqrt((5000 * Eh2) - Eh_squared)
#         coeff[box][guess] = np.max(top / bottom)

# %%
for box in range(16):
    print(hex(np.argsort(coeff2[box, :])[-1]))
# Out:
# 0xca
# 0xfe
# 0xba
# 0xbe
# 0xca
# 0xfe
# 0xba
# 0xbe
# 0xca
# 0xfe
# 0xba
# 0xbe
# 0xca
# 0xfe
# 0xba
# 0xbe

# %%
coeff[0xcb, 0]
# Out:
# 0.9299721307798332

# %%
coeff2.T[0xca, 0]
# Out:
# 0.9455776059753018
